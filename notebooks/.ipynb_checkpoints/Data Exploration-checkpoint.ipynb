# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import requests
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim
from sodapy import Socrata
from pygeocoder import Geocoder
import warnings
warnings.filterwarnings('ignore')

# %%
unique_df = pd.read_csv("../data/unique_austin_shelter.csv")

# %%
unique_df.set_index("animal_id", inplace=True)

# %%
unique_df.columns
# Out:
# Index(['breed', 'color', 'date_in', 'found_location', 'intake_condition',
#        'intake_type', 'name', 'sex', 'fixed', 'date_of_birth', 'date_out',
#        'outcome_subtype', 'outcome_type', 'in_shelter', 'time_in_shelter',
#        'age_in', 'age_out'],
#       dtype='object')

# %% [markdown]
# #### Average time in shelter

# %%
(unique_df.date_out.apply(pd.to_datetime) - unique_df.date_in.apply(pd.to_datetime)).mean()
# Out:
# Timedelta('15 days 12:19:40.914530')

# %% [markdown]
# #### Most common dog name

# %%
unique_df.name.value_counts().head()
# Out:
# Bella    269
# Max      256
# Daisy    203
# Luna     193
# Rocky    188
# Name: name, dtype: int64

# %% [markdown]
# #### How many dogs don't have names

# %%
unique_df.name.isnull().value_counts()
# Out:
# False    31823
# True      8207
# Name: name, dtype: int64

# %% [raw]
# unique_df.coordinates = unique_df.coordinates.str.replace("(", "")
# unique_df.coordinates = unique_df.coordinates.str.replace(")", "")
# unique_df['lat'] = unique_df.coordinates.str.split(",").str[0].astype(float)
# unique_df['long'] = unique_df.coordinates.str.split(",").str[1].astype(float)

# %% [raw]
# from mapsplotlib import mapsplot as mplt
# unique_df.dtypes

# %% [raw]
# map_df = unique_df.loc[(unique_df.lat > 30.08) & (unique_df.lat < 30.52) & (unique_df.long < -97.54) & (unique_df.long > -97.91)]

# %% [raw]
# mplt.register_api_key('AIzaSyAv6GNQfa2MorCAfyh9Ierw6PoS9Ix9N8Y')
# mplt.density_plot(map_df['lat'], map_df['long'])

# %% [markdown]
# #### Number of dogs adopted per outcome type

# %%
unique_df.outcome_type.value_counts().plot.bar(alpha=0.6)

# %%
unique_df.outcome_type.value_counts()
# Out:
# Adoption           17951
# Return to Owner    10323
# Transfer            9631
# Euthanasia          1348
# Died                 166
# Rto-Adopt            160
# Missing               12
# Disposal              12
# Name: outcome_type, dtype: int64

# %% [markdown]
# #### Does intake conditon affect outcome?

# %%
counts = pd.crosstab(unique_df.intake_condition, unique_df.outcome_type)
(counts / counts.sum()).plot.bar(figsize=(20,10), alpha=0.7)

# %% [markdown]
# #### If injured/sick dogs are more likely to be euthanized compared to normal dogs

# %%
unique_df.loc[unique_df.outcome_type == "Euthanasia"].intake_condition.value_counts().plot.bar(alpha=0.7)

# %%
unique_df.loc[unique_df.outcome_type == "Adoption"].intake_condition.value_counts().plot.bar(alpha=0.7)

# %% [markdown]
# #### Does the outcome of a dog change based on gender?

# %%
counts = pd.crosstab(unique_df.outcome_type, unique_df.sex)

# %%
(counts / counts.sum()).plot.bar(stacked=True)

# %% [markdown]
# #### What is the most common abandoned dog breed?

# %%
unique_df.breed.value_counts()[:10]
# Out:
# Pit Bull Mix                 4705
# Chihuahua Shorthair Mix      4644
# Labrador Retriever Mix       4237
# German Shepherd Mix          1781
# Australian Cattle Dog Mix     954
# Dachshund Mix                 773
# Miniature Poodle Mix          582
# Border Collie Mix             573
# Boxer Mix                     560
# Yorkshire Terrier Mix         476
# Name: breed, dtype: int64

# %%
unique_df.breed.value_counts()[:20].plot.bar(figsize=(20,5), alpha=0.7)

# %% [markdown]
# #### What is the most common adopted dog breed?
# *normalie??*

# %%
unique_df.loc[(unique_df.in_shelter == "No") 
              & (unique_df.outcome_type=="Adoption")].breed.value_counts()[:10]
# Out:
# Chihuahua Shorthair Mix      2148
# Labrador Retriever Mix       2134
# Pit Bull Mix                 1726
# German Shepherd Mix           857
# Australian Cattle Dog Mix     510
# Dachshund Mix                 360
# Border Collie Mix             317
# Boxer Mix                     244
# Miniature Poodle Mix          236
# Australian Shepherd Mix       225
# Name: breed, dtype: int64

# %%
unique_df.loc[(unique_df.in_shelter == "No") 
              & (unique_df.outcome_type=="Adoption")].breed.value_counts()[:20].plot.bar(figsize=(20,5), alpha=0.7)

# %% [markdown]
# #### Most common time a dog is admitted

# %%
unique_df.date_in = unique_df.date_in.apply(pd.to_datetime)

# %%
unique_df.date_in.apply(lambda x: x.month).value_counts().plot.pie()

# %%
unique_df.date_in.apply(lambda x: x.day).value_counts().plot.pie()

# %% [markdown]
# #### Most common time a dog is adopted

# %%
unique_df.date_out = unique_df.date_out.apply(pd.to_datetime)

# %%
unique_df.date_out.apply(lambda x: x.month).value_counts().plot.pie()

# %%
unique_df.date_out.apply(lambda x: x.day).value_counts().plot.pie()

# %% [markdown]
# #### Most common age of admitted dogs

# %%
unique_df.age_in.value_counts().plot.bar()

# %% [markdown]
# #### Most common age of adopted dogs

# %%
unique_df.loc[unique_df.outcome_type == "Adoption"]['age_out'].value_counts().plot.bar()

# %% [markdown]
# #### What is the best age to abandon your dog to ensure that it will be better adopted?

# %%
unique_df.loc[unique_df.outcome_type == "Adoption"]['age_in'].value_counts().plot.bar()

# %%
unique_df
# Out:
#                                               breed  \
# animal_id
# A786884                                  Beagle Mix
# A706918                    English Springer Spaniel
# A724273                                 Basenji Mix
# A778404                         German Shepherd Mix
# A682524       Doberman Pinsch/Australian Cattle Dog
# A743852                      Labrador Retriever Mix
# A708452                      Labrador Retriever Mix
# A760053                         Chihuahua Shorthair
# A707375                                    Pit Bull
# A696408                         Chihuahua Shorthair
# A697950    Australian Cattle Dog/Labrador Retriever
# A298074                  Parson Russell Terrier Mix
# A769764                       Yorkshire Terrier Mix
# A682230                                 Maltese Mix
# A749436                               Dachshund Mix
# A759935                      Labrador Retriever Mix
# A666877                               Dachshund Mix
# A732903                      Labrador Retriever Mix
# A769816                             Plott Hound Mix
# A724378                         Tibetan Spaniel Mix
# A745133                     Chihuahua Shorthair Mix
# A721791               Dachshund/Chihuahua Shorthair
# A675555                   German Shepherd/Chow Chow
# A747964                     Miniature Schnauzer Mix
# A787254                         Black Mouth Cur Mix
# A710890                          Great Pyrenees Mix
# A683884                         German Shepherd Mix
# A676263                                Pit Bull Mix
# A736719                      Labrador Retriever Mix
# A770028               American Pit Bull Terrier Mix
# ...                                             ...
# A790425                     Chihuahua Shorthair Mix
# A761683                              Siberian Husky
# A790422                              Siberian Husky
# A790198                               Dachshund Mix
# A790407                              Cocker Spaniel
# A790424                           Staffordshire Mix
# A790420                      Labrador Retriever Mix
# A790280                    Jack Russell Terrier Mix
# A790367                        Belgian Tervuren Mix
# A790397                         Australian Shepherd
# A789484                 Miniature Poodle/Lhasa Apso
# A789444                                   Boxer Mix
# A790432                   Australian Cattle Dog Mix
# A790431          Jack Russell Terrier/Border Collie
# A790430                               Dachshund Mix
# A790279                           Cairn Terrier Mix
# A790218                      Labrador Retriever Mix
# A790426                     Miniature Schnauzer Mix
# A790387                                      Beagle
# A790247              Anatol Shepherd/Great Pyrenees
# A790439                                   Boxer Mix
# A790463                           West Highland Mix
# A790435    Labrador Retriever/Australian Cattle Dog
# A788004                      Labrador Retriever Mix
# A790445                           Staffordshire Mix
# A789901             German Shepherd/Doberman Pinsch
# A790070                         German Shepherd Mix
# A788592                                   Boxer Mix
# A790216                                Pit Bull Mix
# A790182                            Pit Bull/Pointer
#
#                                 color             date_in  \
# animal_id
# A786884                  ['Tricolor'] 2019-01-03 16:19:00
# A706918            ['White', 'Liver'] 2015-07-05 12:59:00
# A724273            ['Sable', 'White'] 2016-04-14 18:43:00
# A778404              ['Black', 'Tan'] 2018-08-14 10:19:00
# A682524               ['Tan', 'Gray'] 2014-06-29 10:38:00
# A743852                 ['Chocolate'] 2017-02-18 12:46:00
# A708452            ['Black', 'White'] 2015-07-30 14:37:00
# A760053              ['White', 'Tan'] 2017-10-11 15:46:00
# A707375            ['Brown', 'White'] 2015-07-11 18:19:00
# A696408                  ['Tricolor'] 2015-02-04 12:58:00
# A697950              ['Tan', 'White'] 2015-03-04 11:22:00
# A298074            ['Black', 'White'] 2015-09-06 14:21:00
# A769764            ['White', 'Black'] 2018-04-09 19:03:00
# A682230                     ['White'] 2014-06-25 16:27:00
# A749436            ['Brown', 'White'] 2017-05-15 09:50:00
# A759935                     ['Black'] 2017-10-09 22:39:00
# A666877              ['Tan', 'White'] 2013-11-08 15:24:00
# A732903            ['Black', 'White'] 2016-08-14 15:02:00
# A769816    ['Brown Brindle', 'White'] 2018-04-10 16:46:00
# A724378            ['Black', 'White'] 2016-04-16 13:36:00
# A745133                       ['Tan'] 2017-03-13 12:50:00
# A721791               ['Brown Merle'] 2016-03-04 14:18:00
# A675555              ['Sable', 'Tan'] 2015-04-04 11:09:00
# A747964             ['White', 'Gray'] 2017-04-27 13:23:00
# A787254            ['Black', 'White'] 2019-01-10 10:19:00
# A710890                     ['White'] 2015-08-29 13:15:00
# A683884              ['Black', 'Tan'] 2014-07-16 15:52:00
# A676263             ['Blue', 'White'] 2014-04-07 11:57:00
# A736719              ['Tan', 'White'] 2016-10-16 10:37:00
# A770028            ['White', 'Brown'] 2018-04-14 12:50:00
# ...                               ...                 ...
# A790425            ['Black', 'White'] 2019-03-10 11:22:00
# A761683             ['Black', 'Gray'] 2019-03-10 10:54:00
# A790422             ['Black', 'Gray'] 2019-03-10 10:54:00
# A790198              ['Black', 'Tan'] 2019-03-06 13:34:00
# A790407              ['Tan', 'White'] 2019-03-09 16:29:00
# A790424                     ['Black'] 2019-03-10 11:16:00
# A790420                      ['Buff'] 2019-03-10 08:28:00
# A790280            ['White', 'Brown'] 2019-03-07 12:46:00
# A790367            ['Brown', 'Black'] 2019-03-09 00:04:00
# A790397       ['Blue Merle', 'White'] 2019-03-09 15:23:00
# A789484                     ['White'] 2019-02-22 13:32:00
# A789444             ['Brown Brindle'] 2019-02-21 16:38:00
# A790432              ['White', 'Red'] 2019-03-10 12:57:00
# A790431            ['Black', 'White'] 2019-03-10 12:37:00
# A790430            ['Black', 'Brown'] 2019-03-10 12:28:00
# A790279              ['Tan', 'Cream'] 2019-03-07 14:06:00
# A790218                 ['Chocolate'] 2019-03-06 15:33:00
# A790426           ['Silver', 'Black'] 2019-03-10 11:45:00
# A790387         ['White', 'Tricolor'] 2019-03-09 13:21:00
# A790247             ['White', 'Gray'] 2019-03-06 18:50:00
# A790439            ['Black', 'White'] 2019-03-10 14:36:00
# A790463                     ['White'] 2019-03-10 17:35:00
# A790435                     ['Black'] 2019-03-10 13:22:00
# A788004                     ['Brown'] 2019-01-24 17:27:00
# A790445             ['Blue', 'White'] 2019-03-10 15:44:00
# A789901              ['Black', 'Tan'] 2019-03-01 15:58:00
# A790070            ['Brown', 'Black'] 2019-03-04 19:16:00
# A788592              ['Tan', 'White'] 2019-02-05 11:18:00
# A790216      ['Brown Tiger', 'White'] 2019-03-06 15:18:00
# A790182              ['Tan', 'White'] 2019-03-06 09:57:00
#
#                                               found_location intake_condition  \
# animal_id
# A786884                          2501 Magin Meadow Dr Austin           Normal
# A706918                             9409 Bluegrass Dr Austin           Normal
# A724273                           2818 Palomino Trail Austin           Normal
# A778404                                               Austin           Normal
# A682524                                800 Grove Blvd Austin           Normal
# A743852                                               Austin           Normal
# A708452                                               Austin           Normal
# A760053                       8800 South First Street Austin           Normal
# A707375                 Galilee Court And Damita Jo Dr Manor           Normal
# A696408                                  9705 Thaxton Austin           Normal
# A697950                                 1501 S Fm 973 Austin           Normal
# A298074                                1801 Westridge Austin           Normal
# A769764                      7500 South Interstate 35 Austin           Normal
# A682230                                 3737 Keats Dr Austin           Normal
# A749436             East Pleasant Valley And Stassney Austin           Normal
# A759935                            4800 Cottonwood St Austin           Normal
# A666877                           Guadalupe/St. Johns Austin           Normal
# A732903                                               Austin          Injured
# A769816                      17833 Basket Flower Bend Travis           Normal
# A724378                                               Austin           Normal
# A745133                     11699 James B Connolly Ln Austin           Normal
# A721791                                   12928 Ceder Travis           Normal
# A675555                           Loyola And Sandshof Austin           Normal
# A747964                          15207 Tacon Ln Pflugerville           Normal
# A787254                                2000 Man O War Travis           Normal
# A710890                             14901 Mossycup Ln Travis           Normal
# A683884                         7619 E Ben White Blvd Austin          Injured
# A676263                                     Elfen Way Austin           Normal
# A736719                           2115 Campfield Pkwy Austin           Normal
# A770028                                               Austin           Normal
# ...                                                      ...              ...
# A790425     Montopolis Drive And East Riverside Drive Austin           Normal
# A761683                          8314 West Highway 71 Austin           Normal
# A790422                          8314 West Highway 71 Austin           Normal
# A790198                         1800 East 51St Street Austin           Normal
# A790407                                               Austin           Normal
# A790424                           400 Saint Elmo Road Austin           Normal
# A790420                                 4434 Frontier Austin           Normal
# A790280                          Parmer And Techridge Austin           Normal
# A790367                            9403 Grouse Meadow Austin           Normal
# A790397                          600 West Carrie Manor Manor           Normal
# A789484                        2104 Blue Meadow Drive Austin           Normal
# A789444            Johnny Morris Road And Loyola Lane Austin           Normal
# A790432                            9000 Sprinkle Road Austin           Normal
# A790431                           Fm 963 And Hiway 71 Austin           Normal
# A790430                      Riverside And Highway 71 Austin           Normal
# A790279                 Bissel Lane And Manchaca Road Austin           Normal
# A790218    Burleson Road And East Ben White Boulevard Austin           Normal
# A790426                             11228 Malin Drive Austin           Normal
# A790387                              5903 Garden Oaks Austin           Normal
# A790247                                 Hancock Drive Austin           Normal
# A790439                        Highway 183 And Fm 969 Austin           Normal
# A790463                       9308 South First Street Austin           Normal
# A790435              Guadalupe Street And 45Th Street Austin           Normal
# A788004                                               Austin          Injured
# A790445          Harris Ridge Road And Sebastian Bend Austin           Normal
# A789901                          14719 Us Hwy 290 East Manor           Normal
# A790070                                               Austin           Normal
# A788592                           225 Maldonado Trail Travis           Normal
# A790216             1809 W Rundberg Ln Apt Number 235 Austin           Normal
# A790182                             1407 Atterbury Ln Austin           Normal
#
#                intake_type        name     sex fixed        date_of_birth  \
# animal_id
# A786884              Stray       Brock    Male   Yes  2017-01-03 00:00:00
# A706918              Stray       Belle  Female   Yes  2007-07-05 00:00:00
# A724273              Stray     Runster    Male    No  2015-04-17 00:00:00
# A778404    Owner Surrender         Max    Male    No  2014-08-14 00:00:00
# A682524              Stray         Rio    Male   Yes  2010-06-29 00:00:00
# A743852    Owner Surrender        Odin    Male   Yes  2015-02-18 00:00:00
# A708452      Public Assist      Mumble    Male    No  2013-07-28 00:00:00
# A760053              Stray         NaN    Male    No  2015-10-11 00:00:00
# A707375              Stray  Candy Cane  Female    No  2015-01-11 00:00:00
# A696408              Stray       Pearl  Female    No  2013-02-04 00:00:00
# A697950              Stray         NaN  Female    No  2014-12-20 00:00:00
# A298074              Stray      Stumpy  Female   Yes  1997-02-07 00:00:00
# A769764              Stray         NaN  Female    No  2017-10-10 00:00:00
# A682230              Stray         NaN  Female    No  2013-12-25 00:00:00
# A749436              Stray         NaN    Male    No  2016-12-15 00:00:00
# A759935              Stray       Dieve  Female    No  2017-08-15 00:00:00
# A666877              Stray       Romeo    Male    No  2012-11-08 00:00:00
# A732903              Stray       Raven  Female    No  2016-05-23 00:00:00
# A769816              Stray     Wallace    Male    No  2013-04-10 00:00:00
# A724378    Owner Surrender       Boxer    Male    No  2012-04-16 00:00:00
# A745133              Stray       Magic    Male    No  2016-03-13 00:00:00
# A721791              Stray         NaN    Male    No  2015-12-23 00:00:00
# A675555              Stray    Guardian    Male   Yes  2012-03-29 00:00:00
# A747964              Stray         NaN    Male    No  2011-04-27 00:00:00
# A787254              Stray   Sprinkles  Female    No                  NaN
# A710890              Stray    The Dude    Male    No  2012-08-29 00:00:00
# A683884              Stray     Blackie    Male   Yes  2012-07-16 00:00:00
# A676263              Stray     Stanley    Male   Yes  2012-04-07 00:00:00
# A736719              Stray     Dreamer  Female   Yes  2004-10-18 00:00:00
# A770028    Owner Surrender    Ladybird  Female    No  2017-09-22 00:00:00
# ...                    ...         ...     ...   ...                  ...
# A790425              Stray         NaN    Male    No                  NaN
# A761683              Stray       Frida  Female   Yes  2016-05-07 00:00:00
# A790422              Stray         Osa  Female    No  2017-02-23 00:00:00
# A790198              Stray      George    Male    No                  NaN
# A790407    Owner Surrender      Quincy    Male   Yes  2009-03-09 00:00:00
# A790424              Stray         NaN  Female    No                  NaN
# A790420              Stray         NaN    Male    No                  NaN
# A790280              Stray         NaN    Male   Yes                  NaN
# A790367              Stray        Yayo    Male    No  2018-06-10 00:00:00
# A790397              Stray        Cash    Male    No  2017-09-10 00:00:00
# A789484              Stray         NaN    Male   Yes  2017-02-22 00:00:00
# A789444              Stray       Khaza    Male    No  2018-02-21 00:00:00
# A790432              Stray         NaN    Male    No                  NaN
# A790431              Stray         NaN    Male    No                  NaN
# A790430              Stray         NaN    Male    No                  NaN
# A790279              Stray         NaN    Male    No                  NaN
# A790218              Stray        Chip    Male    No                  NaN
# A790426              Stray      Lobito    Male    No                  NaN
# A790387    Owner Surrender       Nomad    Male   Yes                  NaN
# A790247              Stray       Fiona  Female    No                  NaN
# A790439              Stray   Patterson  Female   Yes                  NaN
# A790463              Stray         NaN  Female    No                  NaN
# A790435              Stray     Trapper    Male    No  2017-11-10 00:00:00
# A788004      Public Assist      Donkey  Female   Yes                  NaN
# A790445              Stray         NaN  Female    No                  NaN
# A789901              Stray      Beerus    Male    No  2018-11-01 00:00:00
# A790070      Public Assist        Lucy  Female   Yes                  NaN
# A788592              Stray       Rocky    Male   Yes                  NaN
# A790216              Stray       Rajah    Male    No                  NaN
# A790182              Stray        Xena  Female    No                  NaN
#
#                      date_out outcome_subtype     outcome_type in_shelter  \
# animal_id
# A786884   2019-01-08 15:11:00         Partner         Transfer         No
# A706918   2015-07-05 15:13:00             NaN  Return to Owner         No
# A724273   2016-04-21 17:17:00             NaN  Return to Owner         No
# A778404   2018-08-17 18:03:00             NaN         Adoption         No
# A682524   2014-07-02 14:16:00             NaN  Return to Owner         No
# A743852   2017-02-21 17:44:00             NaN  Return to Owner         No
# A708452   2015-08-04 18:17:00             NaN  Return to Owner         No
# A760053   2017-10-15 18:30:00             NaN         Adoption         No
# A707375   2015-11-28 17:31:00             NaN         Adoption         No
# A696408   2015-05-28 11:24:00          Foster         Adoption         No
# A697950   2015-03-08 18:55:00             NaN         Adoption         No
# A298074   2015-09-07 11:40:00             NaN  Return to Owner         No
# A769764   2018-04-13 16:12:00         Partner         Transfer         No
# A682230   2014-06-29 17:26:00         Partner         Transfer         No
# A749436   2017-05-15 13:25:00         Partner         Transfer         No
# A759935   2017-10-17 18:18:00             NaN         Adoption         No
# A666877   2013-11-15 14:53:00         Partner         Transfer         No
# A732903   2016-08-20 15:40:00         Partner         Transfer         No
# A769816   2018-05-02 15:37:00         Partner         Transfer         No
# A724378   2016-04-20 13:11:00             NaN         Adoption         No
# A745133   2017-03-24 12:02:00         Partner         Transfer         No
# A721791   2016-03-08 18:22:00             NaN         Adoption         No
# A675555   2015-04-05 14:35:00             NaN  Return to Owner         No
# A747964   2017-05-01 17:03:00         Partner         Transfer         No
# A787254                   NaT             NaN              NaN        Yes
# A710890   2015-09-06 18:04:00             NaN         Adoption         No
# A683884   2014-09-07 14:37:00             NaN         Adoption         No
# A676263   2014-06-10 19:17:00             NaN         Adoption         No
# A736719   2016-10-18 12:28:00             NaN  Return to Owner         No
# A770028   2018-05-14 13:43:00             NaN         Adoption         No
# ...                       ...             ...              ...        ...
# A790425                   NaT             NaN              NaN        Yes
# A761683   2019-03-10 19:05:00             NaN  Return to Owner         No
# A790422   2019-03-10 17:49:00             NaN  Return to Owner         No
# A790198                   NaT             NaN              NaN        Yes
# A790407   2019-03-10 16:31:00         Partner         Transfer         No
# A790424                   NaT             NaN              NaN        Yes
# A790420                   NaT             NaN              NaN        Yes
# A790280                   NaT             NaN              NaN        Yes
# A790367   2019-03-10 11:24:00             NaN  Return to Owner         No
# A790397   2019-03-10 12:32:00             NaN  Return to Owner         No
# A789484   2019-02-26 11:54:00         Partner         Transfer         No
# A789444   2019-03-10 17:09:00             NaN         Adoption         No
# A790432                   NaT             NaN              NaN        Yes
# A790431                   NaT             NaN              NaN        Yes
# A790430                   NaT             NaN              NaN        Yes
# A790279                   NaT             NaN              NaN        Yes
# A790218                   NaT             NaN              NaN        Yes
# A790426                   NaT             NaN              NaN        Yes
# A790387                   NaT             NaN              NaN        Yes
# A790247                   NaT             NaN              NaN        Yes
# A790439                   NaT             NaN              NaN        Yes
# A790463                   NaT             NaN              NaN        Yes
# A790435   2019-03-10 18:10:00             NaN  Return to Owner         No
# A788004                   NaT             NaN              NaN        Yes
# A790445                   NaT             NaN              NaN        Yes
# A789901   2019-03-10 15:10:00             NaN         Adoption         No
# A790070                   NaT             NaN              NaN        Yes
# A788592                   NaT             NaN              NaN        Yes
# A790216                   NaT             NaN              NaN        Yes
# A790182                   NaT             NaN              NaN        Yes
#
#                        time_in_shelter  age_in  age_out
# animal_id
# A786884      4 days 22:52:00.000000000     2.0      2.0
# A706918      0 days 02:14:00.000000000     8.0      8.0
# A724273      6 days 22:34:00.000000000     1.0      1.0
# A778404      3 days 07:44:00.000000000     4.0      4.0
# A682524      3 days 03:38:00.000000000     4.0      4.0
# A743852      3 days 04:58:00.000000000     2.0      2.0
# A708452      5 days 03:40:00.000000000     2.0      2.0
# A760053      4 days 02:44:00.000000000     2.0      2.0
# A707375    139 days 23:12:00.000000000     0.5      1.0
# A696408    112 days 22:26:00.000000000     2.0      2.0
# A697950      4 days 07:33:00.000000000     0.5      0.5
# A298074      0 days 21:19:00.000000000    19.0     19.0
# A769764      3 days 21:09:00.000000000     0.5      1.0
# A682230      4 days 00:59:00.000000000     0.5      1.0
# A749436      0 days 03:35:00.000000000     0.5      0.5
# A759935      7 days 19:39:00.000000000     0.5      0.5
# A666877      6 days 23:29:00.000000000     1.0      1.0
# A732903      6 days 00:38:00.000000000     0.5      0.5
# A769816     21 days 22:51:00.000000000     5.0      5.0
# A724378      3 days 23:35:00.000000000     4.0      4.0
# A745133     10 days 23:12:00.000000000     1.0      1.0
# A721791      4 days 04:04:00.000000000     0.5      0.5
# A675555      1 days 03:26:00.000000000     3.0      3.0
# A747964      4 days 03:40:00.000000000     6.0      6.0
# A787254                            NaN     NaN      NaN
# A710890      8 days 04:49:00.000000000     3.0      3.0
# A683884     52 days 22:45:00.000000000     2.0      2.0
# A676263     64 days 07:20:00.000000000     2.0      2.0
# A736719      2 days 01:51:00.000000000    12.0     12.0
# A770028     30 days 00:53:00.000000000     1.0      1.0
# ...                                ...     ...      ...
# A790425                            NaN     NaN      NaN
# A761683      0 days 08:11:00.000000000     3.0      3.0
# A790422      0 days 06:55:00.000000000     2.0      2.0
# A790198                            NaN     NaN      NaN
# A790407      1 days 00:02:00.000000000    10.0     10.0
# A790424                            NaN     NaN      NaN
# A790420                            NaN     NaN      NaN
# A790280                            NaN     NaN      NaN
# A790367      1 days 11:20:00.000000000     1.0      1.0
# A790397      0 days 21:09:00.000000000     1.0      1.0
# A789484      3 days 22:22:00.000000000     2.0      2.0
# A789444     17 days 00:31:00.000000000     1.0      1.0
# A790432                            NaN     NaN      NaN
# A790431                            NaN     NaN      NaN
# A790430                            NaN     NaN      NaN
# A790279                            NaN     NaN      NaN
# A790218                            NaN     NaN      NaN
# A790426                            NaN     NaN      NaN
# A790387                            NaN     NaN      NaN
# A790247                            NaN     NaN      NaN
# A790439                            NaN     NaN      NaN
# A790463                            NaN     NaN      NaN
# A790435      0 days 04:48:00.000000000     1.0      1.0
# A788004                            NaN     NaN      NaN
# A790445                            NaN     NaN      NaN
# A789901      8 days 23:12:00.000000000     0.5      0.5
# A790070                            NaN     NaN      NaN
# A788592                            NaN     NaN      NaN
# A790216                            NaN     NaN      NaN
# A790182                            NaN     NaN      NaN
#
# [40030 rows x 17 columns]
